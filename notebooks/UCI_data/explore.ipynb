# %%
import pandas as pd
import os

path = os.path.join("..", "data", "UCI HAR Dataset", "test")
subject_file = os.path.join(path, "subject_test.txt")
x_test_file = os.path.join(path, "X_test.txt")
y_test_file = os.path.join(path, "y_test.txt")
subject = pd.read_csv(subject_file, header=None)
x = pd.read_csv(x_test_file, header=None)
y = pd.read_csv(y_test_file, header=None)

print(subject.head())
print(x.head())
print(y.head())
# print(subject[0].tolist())
# print(subject)
# Out:
#    0
# 0  2
# 1  2
# 2  2
# 3  2
# 4  2
#                                                    0
# 0    2.5717778e-001 -2.3285230e-002 -1.4653762e-0...
# 1    2.8602671e-001 -1.3163359e-002 -1.1908252e-0...
# 2    2.7548482e-001 -2.6050420e-002 -1.1815167e-0...
# 3    2.7029822e-001 -3.2613869e-002 -1.1752018e-0...
# 4    2.7483295e-001 -2.7847788e-002 -1.2952716e-0...
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5
